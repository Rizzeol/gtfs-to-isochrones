# %%
from gtfs_graph.geo import get_isochrone

# %%
# %%time
global_buffer, all_paths = get_isochrone(46.518678, 6.625518, 25)
# Out:
# CPU times: user 6.01 s, sys: 561 ms, total: 6.58 s
# Wall time: 6.62 s

# %%
global_buffer.plot()

# %%
from ipyleaflet import Map, Marker, GeoJSON
m = Map(center=(46.518987, 6.561948))
m.add_layer(Marker(location=(46.518678, 6.625518)))
m.add_layer(GeoJSON(data=global_buffer.__geo_interface__))
m
# Out:
# Map(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map …
